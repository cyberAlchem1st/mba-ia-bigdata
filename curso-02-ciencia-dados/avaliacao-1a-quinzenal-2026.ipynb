# %% [markdown]
# #CURSO 2 - CIENCIA DE DADOS, APRENDIZADO DE MÁQUINA e DATA MINING
# ##PROFa. Roseli A F Romero
#
# ## AVALIAÇÃO QUINZENAL

# %%
# Celula de importacoes mais utilizadas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from scipy.stats import skew, kurtosis

# %% [markdown]
# Para as questões de 01 a 05, considere a base de dados sobre informações de apartamentos: **aptos.xlsx** (formato excel) e faça a sua leitura. O objetivo desse dataset é relacionar o preço de um imóvel considerando suas diferentes características (ou atributos).

# %% [markdown]
# ### Questão 01.
#
# Fazendo a leitura dos dados,
# e realização inicial desta base de dados, o que se pode afirmar:
#
# a) Existem 3 atributos numéricos e 41 atributos categóricos <br>
# b) Não existem valores faltantes <br>
# c) Todos os atributos são categóricos <br>
# d) Existem 2 atributos categóricos e o restante é do tipo numérico <br>
# e) N.D.A. <br>

# %% [markdown]
# ### Questão 02.
# Considere o atributo "area" e realize o preenchimentos dos dados faltantes (a imputação) de dois modos:
# (1) pelo valor da área média
# (2) pela média da área dos apt. com 2 dormitórios. Quais são os valores obtidos:
#
# a) 71.00 e 151.23 </br>
# b) 152.34 e 192.47 </br>
# c) 188.05 e 193.25 </br>
# d) 192.47 e 151.22 </br>
# e) N.D.A

# %% [markdown]
# ## Questão 03
#
# Faça a imputação usando a média da área de apartamentos com 2 dormitórios e em seguida calcule os 4 momentos dos atributos numéricos: "área" e "valor_R$":
#
# a) Média: 120.41 e 123452.83; Variância: 122225.03 e 5.424456e+08; Obliquidade: -0.61 e 0.53; Achatamento: -0.45 e -0.22<br>
# b) Média: 188.40 e 122659.09; Variância: 6.758400e+03 e
# 4.304602e+09; Obliquidade: 0.20 e 0.69; Achatamento: -0.45
# e -0.46 <br>
# c) Média: 410.24 e 193334.83; Variância: 5.77777e+03 e 2.9567e+07; Obliquidade: -0.61 e 0.53; Achatamento: -0.57 e -0.02<br>
# d) Média: 678.26 e 183345.25; Variância: Variância: 122225.03e+03 e 3.424456e+09; Obliquidade: -0.31 e -0.53; Achatamento: -0.05 e -0.02<br>
# e) Média: 411.12 e 183245.22; Variância: 0.01 e 0.24; Obliquidade: -0.61 e 0.53; Achatamento: -0.35 e -0.12 </br>

# %% [markdown]
# ## Questão 04
#
# Considere os seguintes atributos: "conservacao", "idade_real", "dormitorio", "valor_R$".
# Transformar os que são categóricos em numéricos, usando a função Label Encoder. Calcular a matriz de correlação referente a esses atributos e indicar qual das alternativas está incorreta:
#
# a) A análise mostra que alguns atributos apresentam correlação positiva com o valor do imóvel, como idade_real e dormitorio, enquanto conservacao_numeric apresenta correlação fraca e negativa. </br>
# b) A conservação apresenta relação moderada, indicando que imóveis em melhor estado tendem a valer mais. </br>
# c) O número de dormitórios também tem correlação moderada, mostrando que imóveis maiores costumam ser mais caros. </br>
# d) A conservação tem correlação fraca, sugerindo que a idade do prédio influencia pouco no preço. <br>
# e) A idade_real e o número de dormitórios são os fatores menos relevantes em relação ao valor do imóvel.

# %% [markdown]
# ## Questão 05
#
# Considerando o atributo "area". As cercas inferior e superior correspondente são:
#
# a) LF = -38.75 e UF = 415.25 <br>
# b) LF = 50 e UF = 350 <br>
# c) LF = 38 e UF = 384 <br>
# d) LF = -40.25 e UF = 415.00 <br>
# e) N.D.A.
