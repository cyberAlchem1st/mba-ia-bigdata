# %% [markdown]
# # <font color="red"> MBA em IA e Big Data</font>
# ## <span style="color:red">Linguagens e Ferramentas para Inteligência Artificial e Big Data (Python e SQL)</span>
#
# ### <span style="color:darkred">Avaliação</span>
#
# *Leandro Franco de Souza*<br>
# *ICMC/USP São Carlos*

# %% [markdown]
# ## Questão 1
#
# Dada a lista de registos de temperatura `(Cidade, Temperatura_C)`, crie uma nova lista apenas com os nomes das cidades onde a temperatura é superior a 30°C.
#
# ```python
# temps = [('São Carlos', 28), ('Ribeirão Preto', 34), ('Campinas', 31), ('Santos', 29), ('Cuiabá', 38)]
# ```
#
# a) ['São Carlos', 'Cuiabá']
# b) ['Ribeirão Preto', 'Campinas', 'Cuiabá']
# c) ['Cuiabá']
# d) ['Ribeirão Preto', 'Cuiabá']

# %%
# Implemente seu código aqui

# %% [markdown]
# ## Questão 2
#
# Crie uma matriz identidade 6x6 usando `numpy`. Substitua todos os elementos da submatriz central (linhas 2 a 4 e colunas 2 a 4) pelo valor **5**. Qual é a soma de todos os elementos da matriz resultante?
#
# a) 48
# b) 32
# c) 36
# d) 50

# %%
import numpy as np
# Implemente seu código aqui

# %% [markdown]
# ## Questão 3
#
# Escreva uma função que receba uma frase e retorne um dicionário com a contagem de caracteres (incluindo espaços). Para a frase `"IA e Big Data"`, qual o valor associado à chave `'a'`?
#
# a) 1
# b) 3
# c) 2
# d) 0

# %%
# Implemente seu código aqui

# %% [markdown]
# ## Questão 4
#
# No ficheiro `sales2.csv`, existem valores faltantes na coluna **Online**. Preencha os valores faltantes (NaN) com o valor **0.0**. Após esse procedimento, quantas linhas totais existem no dataframe original?
#
# a) 88
# b) 80
# c) 102
# d) 75

# %%
import pandas as pd
# Implemente seu código aqui

# %% [markdown]
# ## Questão 5
#
# Utilizando o ficheiro `tips.csv`, qual é a correlação entre o valor da conta (**total_bill**) e a gorjeta (**tip**)?
#
# a) 0.556
# b) 0.675
# c) 0.892
# d) 0.697

# %%
import pandas as pd
# Implemente seu código aqui

# %% [markdown]
# ## Questão 6
#
# Em um sistema de vendas, temos as tabelas Clientes(ClienteID, Nome) e Pedidos(PedidoID, DataPedido, ClienteID), com a chave estrangeira Pedidos.ClienteID -> Clientes.ClienteID. Um usuário tenta inserir um pedido com ClienteID = 999, mas o comando é rejeitado pelo SGBD. Qual é a causa?
#
# a) A tabela Pedidos não possui chave primária definida.
#
# b) O valor 999 para ClienteID não existe na tabela Clientes, violando a integridade referencial.
#
# c) A coluna DataPedido deveria ser uma chave estrangeira.
#
# d) O SGBD exige que toda tabela tenha ao menos duas chaves estrangeiras.

# %% [markdown]
# ## Questão 7
#
# Qual das alternativas representa corretamente um conjunto de responsabilidades típicas de um Sistema Gerenciador de Bancos de Dados (SGBD)?
#
# a) Controle de concorrência, recuperação de falhas, garantia de integridade dos dados e independência física dos dados.
#
# b) Otimização de consultas, gerenciamento de índices, escalonamento de execução de processos e recuperação de falhas.
#
# c) Controle de transações, abstração do armazenamento, renderização de dashboards e imposição de restrições de integridade.
#
# d) Gerenciamento de buffers, controle de acesso aos dados, compressão de arquivos do sistema e gerenciamento de drivers de dispositivo.

# %% [markdown]
# ## Questão 8
#
# Em um sistema hospitalar, há uma tabela Consultas(ConsultaID, PacienteID, DataConsulta). A equipe deseja identificar os pacientes que realizaram exatamente 3 consultas. Qual consulta SQL retorna esse conjunto de identificadores?
#
# a) SELECT PacienteID
#
# FROM Consultas
#
# WHERE COUNT(*) = 3
#
# GROUP BY PacienteID;<br><br>
#
# b) SELECT PacienteID, COUNT(n_consultas)
#
# FROM Consultas
#
# GROUP BY PacienteID
#
# WHERE COUNT(n_consultas) = 3;<br><br>
#
# c) SELECT PacienteID
#
# FROM Consultas
#
# HAVING COUNT(*) = 3;<br><br>
#
# d) SELECT PacienteID
#
# FROM Consultas
#
# GROUP BY PacienteID
#
# HAVING COUNT(*) = 3;<br><br>

# %% [markdown]
# ##Considere o seguinte esquema para as próximas 2 questões:
#
# Autores = {AutorID, NomeAutor}
#
# Livros = {LivroID, Titulo, AutorID, Preco}
#
#  Livros.AutorID -> Autores.AutorID
#
# Vendas = {VendaID, DataVenda}
#
# ItensVenda = {VendaID, LivroID, Quantidade}
#
#  ItensVenda.VendaID -> Vendas.VendaID
#
#  ItensVenda.LivroID -> Livros.LivroID

# %% [markdown]
# ## Questão 9
#
# Qual comando SQL calcula a quantidade total vendida de cada Titulo?
#
# a) SELECT Titulo, Preco
#
#  FROM Livros;<br><br>
#
# b) SELECT l.Titulo, i.Quantidade
#
#  FROM Livros l
#
#  JOIN ItensVenda i ON l.LivroID = i.LivroID;<br><br>
#
# c) SELECT l.Titulo, SUM(i.Quantidade)
#
#  FROM Livros l
#
#  JOIN ItensVenda i ON l.LivroID = i.LivroID
#
#  GROUP BY l.Titulo;<br><br>
#
# d) SELECT SUM(Quantidade)
#
#  FROM ItensVenda;<br><br>

# %% [markdown]
# ## Questão 10
#
# Qual comando SQL retorna os títulos dos livros cujo preço é maior que o preço médio de todos os livros cadastrados?
#
# a) SELECT Titulo
#
# FROM Livros
#
# WHERE Preco > (
#
# SELECT AVG(Preco)
#
# FROM Livros);<br><br>
#
# b) SELECT Titulo
#
# FROM Livros
#
# WHERE Preco > AVG(Preco);<br><br>
#
# c) SELECT l.Titulo
#
# FROM Livros l
#
# WHERE EXISTS (
#
# SELECT AVG(Preco)
#
# FROM Livros
#
# WHERE l.Preco > AVG(Preco)
#
# );<br><br>
#
# d) SELECT Titulo
#
# FROM Livros
#
# GROUP BY Titulo
#
# HAVING Preco > (
#
# SELECT AVG(Preco)
#
# FROM Livros
#
# );
